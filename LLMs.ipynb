# %%
# !pip install openai-whisper
# Out:
# Collecting openai-whisper
#   Downloading openai_whisper-20250625.tar.gz (803 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 16.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (10.7.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (0.60.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (2.0.2)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (0.9.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (4.67.1)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.11/dist-packages (from openai-whisper) (3.2.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->openai-whisper) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken->openai-whisper) (2.32.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->openai-whisper)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->openai-whisper)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->openai-whisper)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->openai-whisper)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->openai-whisper)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->openai-whisper)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->openai-whisper)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->openai-whisper)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->openai-whisper)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->openai-whisper)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->openai-whisper) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->openai-whisper) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 61.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.0 MB/s eta 0:00:00
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=94a5e14c941579c56a4b56138a3e6f8e63bd01b580ac14ad7302255a00c99213
#   Stored in directory: /root/.cache/pip/wheels/32/d2/9a/801b5cc5b2a1af2e280089b71c326711a682fc1d50ea29d0ed
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 openai-whisper-20250625

# %%
# !nvidia-smi
# Out:
# Thu Jul 17 16:35:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
video_url = input()
# Out:
# https://youtu.be/l0FvnARfGKg?si=fg3wM3vdunhYBpEj

# %%
# !pip install -q yt-dlp
# !apt-get install -y ffmpeg
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 63.7 MB/s eta 0:00:00
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import yt_dlp

def download_and_get_title(url):
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': 'videoplayback.%(ext)s',  # save using title as filename
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
    }

    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)  # downloads + returns metadata
        title = info.get('title', 'unknown_title')
        print(f"Downloaded: {title}.mp3")
        return title

# %%
title = download_and_get_title(video_url)
# Out:
# [youtube] Extracting URL: https://youtu.be/l0FvnARfGKg?si=fg3wM3vdunhYBpEj
# [youtube] l0FvnARfGKg: Downloading webpage
# [youtube] l0FvnARfGKg: Downloading tv client config
# [youtube] l0FvnARfGKg: Downloading player 69b31e11-main
# [youtube] l0FvnARfGKg: Downloading tv player API JSON
# [youtube] l0FvnARfGKg: Downloading ios player API JSON
# [youtube] l0FvnARfGKg: Downloading m3u8 information
# [info] l0FvnARfGKg: Downloading 1 format(s): 251
# [download] Destination: videoplayback.webm
# [download] 100% of    5.78MiB in 00:00:00 at 10.86MiB/s
# [ExtractAudio] Destination: videoplayback.mp3
# Deleting original file videoplayback.webm (pass -k to keep)
# Downloaded: THIS Leetcode Strategy Got Me Multiple Big Tech Offers..mp3

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
import whisper

model = whisper.load_model("small")
# Out:
# 100%|███████████████████████████████████████| 461M/461M [00:14<00:00, 34.2MiB/s]

# %%
result = model.transcribe("videoplayback.mp3")

# %%
result
# Out:
# {'text': " I applied this exact Leak Code strategy and I was able to secure offers from Google, Amazon, Microsoft, Automall, and many more within three months of applying the strategy. Hi, my name is Messy Mungle and if you don't already know me, I'm a software engineer at Google and I created a lot of tech career advice content on Instagram, LinkedIn, and now YouTube as well. So make sure to hit the subscribe button and follow my other pages as well. So the number one thing that people get stuck on is what programming language do you use for an interview? Now usually programming languages don't matter, especially for fan companies. So unless you're applying for a specific role that requires you to interview in a specific language, choose whatever language that you are comfortable using. Now I say this with a little grain of salt because I actually failed one of my interviews because I was using C++ and I know this language executes faster than most other languages. However, I got rejected just because of the sheer amount of lines of code I had to write which could have been done in basically five to 10 lines of code if I was to use Python. So really what matters is the speed of which you program in and how quickly you're able to solve the problem. So my advice for you when you're choosing a programming language is actually to first look at that question. If it's a string related question where you have to take an input from the stream and then output it, etc, etc, just use the language like Python. It's much faster than using a language like C++ which requires you to add additional lines of code just to process that data. But generally speaking, choosing a programming language does not matter. Next let's talk about time complexity and space complexity. I do not care what phase of engineering you're in. If you're an intern, if you're looking for a new grad, if you're looking for senior engineering roles, time and space complexity is going to be asked. You should really know all of your own notations. It's actually this chart that I always use before going into any interview. You should always be able to look at your code and figure out what the space and time complexity of your algorithm is. This is definitely definitely going to be asked if you're an intern or a new grad, but even for senior engineering roles, sometimes it's asked. Now before I dive into the exact lead code strategy that I took, I want to talk about DSA fundamentals. If you don't know your DSA fundamentals, you're not going to be efficient with lead code. In fact, many of the interviews that I've taken in the past have asked me the most basic question that I learned back in like second year of college. For example, one of my interview questions in a top company was to implement a hash map and another one was to implement LRU cache. So this is why I say to make sure that you know your DSA fundamentals because you don't know when these questions could be asked. And the other thing is if you know your fundamentals very well, then you're going to be able to choose the correct data structure or algorithm that's required in order to solve a lead code problem. Now let's finally move on to the exact lead code strategy I used in order to crack all these fake companies. Number one, I suggest you get lead code premium or at least the CTC I've bought. I don't think lead code premium is required when you're just starting off, but if you're within one to two month mark of your interviews, I highly recommend getting the lead code premium so that you can solve the most frequently asked company questions. And I truly think that CTC I book is very good to have just again to brush over your fundamentals and kind of review the answers and how you go about thinking them in the first place. Now the exact strategy that I took is that number one, you want to go over arrays, link list and maps. Now obviously, first of all, you want to make sure that you understand what these data str ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.84,
#    'text': ' I applied this exact Leak Code strategy and I was able to secure offers from Google, Amazon,',
#    'tokens': [50364,
#     286,
#     6456,
#     341,
#     1900,
#     1456,
#     514,
#     15549,
#     5206,
#     293,
#     286,
#     390,
#     1075,
#     281,
#     7144,
#     7736,
#     490,
#     3329,
#     11,
#     6795,
#     11,
#     50606],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.84,
#    'end': 9.52,
#    'text': ' Microsoft, Automall, and many more within three months of applying the strategy.',
#    'tokens': [50606,
#     8116,
#     11,
#     24619,
#     336,
#     11,
#     293,
#     867,
#     544,
#     1951,
#     1045,
#     2493,
#     295,
#     9275,
#     264,
#     5206,
#     13,
#     50840],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 2,
#    'seek': 0,
#    'start': 9.52,
#    'end': 13.34,
#    'text': " Hi, my name is Messy Mungle and if you don't already know me, I'm a software engineer at",
#    'tokens': [50840,
#     2421,
#     11,
#     452,
#     1315,
#     307,
#     9847,
#     88,
#     376,
#     1063,
#     306,
#     293,
#     498,
#     291,
#     500,
#     380,
#     1217,
#     458,
#     385,
#     11,
#     286,
#     478,
#     257,
#     4722,
#     11403,
#     412,
#     51031],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 3,
#    'seek': 0,
#    'start': 13.34,
#    'end': 18.56,
#    'text': ' Google and I created a lot of tech career advice content on Instagram, LinkedIn, and',
#    'tokens': [51031,
#     3329,
#     293,
#     286,
#     2942,
#     257,
#     688,
#     295,
#     7553,
#     3988,
#     5192,
#     2701,
#     322,
#     5281,
#     11,
#     20657,
#     11,
#     293,
#     51292],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 4,
#    'seek': 0,
#    'start': 18.56,
#    'end': 19.68,
#    'text': ' now YouTube as well.',
#    'tokens': [51292, 586, 3088, 382, 731, 13, 51348],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 5,
#    'seek': 0,
#    'start': 19.68,
#    'end': 23.52,
#    'text': ' So make sure to hit the subscribe button and follow my other pages as well.',
#    'tokens': [51348,
#     407,
#     652,
#     988,
#     281,
#     2045,
#     264,
#     3022,
#     2960,
#     293,
#     1524,
#     452,
#     661,
#     7183,
#     382,
#     731,
#     13,
#     51540],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 6,
#    'seek': 0,
#    'start': 23.52,
#    'end': 29.12,
#    'text': ' So the number one thing that people get stuck on is what programming language do you use',
#    'tokens': [51540,
#     407,
#     264,
#     1230,
#     472,
#     551,
#     300,
#     561,
#     483,
#     5541,
#     322,
#     307,
#     437,
#     9410,
#     2856,
#     360,
#     291,
#     764,
#     51820],
#    'temperature': 0.0,
#    'avg_logprob': -0.21245742566657788,
#    'compression_ratio': 1.605421686746988,
#    'no_speech_prob': 0.0021484806202352047},
#   {'id': 7,
#    'seek': 2912,
#    'start': 29.12,
#    'end': 30.12,
#    'text': ' for an interview?',
#    'tokens': [50364, 337, 364, 4049, 30, 50414],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 8,
#    'seek': 2912,
#    'start': 30.12,
#    'end': 34.32,
#    'text': " Now usually programming languages don't matter, especially for fan companies.",
#    'tokens': [50414,
#     823,
#     2673,
#     9410,
#     8650,
#     500,
#     380,
#     1871,
#     11,
#     2318,
#     337,
#     3429,
#     3431,
#     13,
#     50624],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 9,
#    'seek': 2912,
#    'start': 34.32,
#    'end': 38.72,
#    'text': " So unless you're applying for a specific role that requires you to interview in a specific",
#    'tokens': [50624,
#     407,
#     5969,
#     291,
#     434,
#     9275,
#     337,
#     257,
#     2685,
#     3090,
#     300,
#     7029,
#     291,
#     281,
#     4049,
#     294,
#     257,
#     2685,
#     50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 10,
#    'seek': 2912,
#    'start': 38.72,
#    'end': 42.24,
#    'text': ' language, choose whatever language that you are comfortable using.',
#    'tokens': [50844,
#     2856,
#     11,
#     2826,
#     2035,
#     2856,
#     300,
#     291,
#     366,
#     4619,
#     1228,
#     13,
#     51020],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 11,
#    'seek': 2912,
#    'start': 42.24,
#    'end': 46.96,
#    'text': ' Now I say this with a little grain of salt because I actually failed one of my interviews',
#    'tokens': [51020,
#     823,
#     286,
#     584,
#     341,
#     365,
#     257,
#     707,
#     12837,
#     295,
#     5139,
#     570,
#     286,
#     767,
#     7612,
#     472,
#     295,
#     452,
#     12318,
#     51256],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 12,
#    'seek': 2912,
#    'start': 46.96,
#    'end': 52.84,
#    'text': ' because I was using C++ and I know this language executes faster than most other languages.',
#    'tokens': [51256,
#     570,
#     286,
#     390,
#     1228,
#     383,
#     25472,
#     293,
#     286,
#     458,
#     341,
#     2856,
#     4454,
#     1819,
#     4663,
#     813,
#     881,
#     661,
#     8650,
#     13,
#     51550],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 13,
#    'seek': 2912,
#    'start': 52.84,
#    'end': 57.760000000000005,
#    'text': ' However, I got rejected just because of the sheer amount of lines of code I had to write',
#    'tokens': [51550,
#     2908,
#     11,
#     286,
#     658,
#     15749,
#     445,
#     570,
#     295,
#     264,
#     23061,
#     2372,
#     295,
#     3876,
#     295,
#     3089,
#     286,
#     632,
#     281,
#     2464,
#     51796],
#    'temperature': 0.0,
#    'avg_logprob': -0.16908001695942676,
#    'compression_ratio': 1.7525083612040133,
#    'no_speech_prob': 0.03620551526546478},
#   {'id': 14,
#    'seek': 5776,
#    'start': 57.879999999999995,
#    'end': 62.96,
#    'text': ' which could have been done in basically five to 10 lines of code if I was to use Python.',
#    'tokens': [50370,
#     597,
#     727,
#     362,
#     668,
#     1096,
#     294,
#     1936,
#     1732,
#     281,
#     1266,
#     3876,
#     295,
#     3089,
#     498,
#     286,
#     390,
#     281,
#     764,
#     15329,
#     13,
#     50624],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 15,
#    'seek': 5776,
#    'start': 62.96,
#    'end': 68.03999999999999,
#    'text': " So really what matters is the speed of which you program in and how quickly you're able",
#    'tokens': [50624,
#     407,
#     534,
#     437,
#     7001,
#     307,
#     264,
#     3073,
#     295,
#     597,
#     291,
#     1461,
#     294,
#     293,
#     577,
#     2661,
#     291,
#     434,
#     1075,
#     50878],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 16,
#    'seek': 5776,
#    'start': 68.03999999999999,
#    'end': 69.56,
#    'text': ' to solve the problem.',
#    'tokens': [50878, 281, 5039, 264, 1154, 13, 50954],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 17,
#    'seek': 5776,
#    'start': 69.56,
#    'end': 73.36,
#    'text': " So my advice for you when you're choosing a programming language is actually to first",
#    'tokens': [50954,
#     407,
#     452,
#     5192,
#     337,
#     291,
#     562,
#     291,
#     434,
#     10875,
#     257,
#     9410,
#     2856,
#     307,
#     767,
#     281,
#     700,
#     51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 18,
#    'seek': 5776,
#    'start': 73.36,
#    'end': 74.52,
#    'text': ' look at that question.',
#    'tokens': [51144, 574, 412, 300, 1168, 13, 51202],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 19,
#    'seek': 5776,
#    'start': 74.52,
#    'end': 79.16,
#    'text': " If it's a string related question where you have to take an input from the stream and",
#    'tokens': [51202,
#     759,
#     309,
#     311,
#     257,
#     6798,
#     4077,
#     1168,
#     689,
#     291,
#     362,
#     281,
#     747,
#     364,
#     4846,
#     490,
#     264,
#     4309,
#     293,
#     51434],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 20,
#    'seek': 5776,
#    'start': 79.16,
#    'end': 83.03999999999999,
#    'text': ' then output it, etc, etc, just use the language like Python.',
#    'tokens': [51434,
#     550,
#     5598,
#     309,
#     11,
#     5183,
#     11,
#     5183,
#     11,
#     445,
#     764,
#     264,
#     2856,
#     411,
#     15329,
#     13,
#     51628],
#    'temperature': 0.0,
#    'avg_logprob': -0.11978841460911574,
#    'compression_ratio': 1.6691176470588236,
#    'no_speech_prob': 0.12246483564376831},
#   {'id': 21,
#    'seek': 8304,
#    'start': 83.04,
#    'end': 88.0,
#    'text': " It's much faster than using a language like C++ which requires you to add additional lines",
#    'tokens': [50364,
#     467,
#     311,
#     709,
#     4663,
#     813,
#     1228,
#     257,
#     2856,
#     411,
#     383,
#     25472,
#     597,
#     7029,
#     291,
#     281,
#     909,
#     4497,
#     3876,
#     50612],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 22,
#    'seek': 8304,
#    'start': 88.0,
#    'end': 90.64,
#    'text': ' of code just to process that data.',
#    'tokens': [50612, 295, 3089, 445, 281, 1399, 300, 1412, 13, 50744],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 23,
#    'seek': 8304,
#    'start': 90.64,
#    'end': 94.64,
#    'text': ' But generally speaking, choosing a programming language does not matter.',
#    'tokens': [50744,
#     583,
#     5101,
#     4124,
#     11,
#     10875,
#     257,
#     9410,
#     2856,
#     775,
#     406,
#     1871,
#     13,
#     50944],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 24,
#    'seek': 8304,
#    'start': 94.64,
#    'end': 97.72,
#    'text': " Next let's talk about time complexity and space complexity.",
#    'tokens': [50944,
#     3087,
#     718,
#     311,
#     751,
#     466,
#     565,
#     14024,
#     293,
#     1901,
#     14024,
#     13,
#     51098],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 25,
#    'seek': 8304,
#    'start': 97.72,
#    'end': 101.12,
#    'text': " I do not care what phase of engineering you're in.",
#    'tokens': [51098,
#     286,
#     360,
#     406,
#     1127,
#     437,
#     5574,
#     295,
#     7043,
#     291,
#     434,
#     294,
#     13,
#     51268],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 26,
#    'seek': 8304,
#    'start': 101.12,
#    'end': 104.28,
#    'text': " If you're an intern, if you're looking for a new grad, if you're looking for senior",
#    'tokens': [51268,
#     759,
#     291,
#     434,
#     364,
#     2154,
#     11,
#     498,
#     291,
#     434,
#     1237,
#     337,
#     257,
#     777,
#     2771,
#     11,
#     498,
#     291,
#     434,
#     1237,
#     337,
#     7965,
#     51426],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 27,
#    'seek': 8304,
#    'start': 104.28,
#    'end': 109.52000000000001,
#    'text': ' engineering roles, time and space complexity is going to be asked.',
#    'tokens': [51426,
#     7043,
#     9604,
#     11,
#     565,
#     293,
#     1901,
#     14024,
#     307,
#     516,
#     281,
#     312,
#     2351,
#     13,
#     51688],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 28,
#    'seek': 8304,
#    'start': 109.52000000000001,
#    'end': 111.96000000000001,
#    'text': ' You should really know all of your own notations.',
#    'tokens': [51688,
#     509,
#     820,
#     534,
#     458,
#     439,
#     295,
#     428,
#     1065,
#     406,
#     763,
#     13,
#     51810],
#    'temperature': 0.0,
#    'avg_logprob': -0.12507920111379317,
#    'compression_ratio': 1.7525773195876289,
#    'no_speech_prob': 0.06559359282255173},
#   {'id': 29,
#    'seek': 11196,
#    'start': 111.96,
#    'end': 116.19999999999999,
#    'text': " It's actually this chart that I always use before going into any interview.",
#    'tokens': [50364,
#     467,
#     311,
#     767,
#     341,
#     6927,
#     300,
#     286,
#     1009,
#     764,
#     949,
#     516,
#     666,
#     604,
#     4049,
#     13,
#     50576],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 30,
#    'seek': 11196,
#    'start': 116.19999999999999,
#    'end': 120.32,
#    'text': ' You should always be able to look at your code and figure out what the space and time',
#    'tokens': [50576,
#     509,
#     820,
#     1009,
#     312,
#     1075,
#     281,
#     574,
#     412,
#     428,
#     3089,
#     293,
#     2573,
#     484,
#     437,
#     264,
#     1901,
#     293,
#     565,
#     50782],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 31,
#    'seek': 11196,
#    'start': 120.32,
#    'end': 122.0,
#    'text': ' complexity of your algorithm is.',
#    'tokens': [50782, 14024, 295, 428, 9284, 307, 13, 50866],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 32,
#    'seek': 11196,
#    'start': 122.0,
#    'end': 126.19999999999999,
#    'text': " This is definitely definitely going to be asked if you're an intern or a new grad, but",
#    'tokens': [50866,
#     639,
#     307,
#     2138,
#     2138,
#     516,
#     281,
#     312,
#     2351,
#     498,
#     291,
#     434,
#     364,
#     2154,
#     420,
#     257,
#     777,
#     2771,
#     11,
#     457,
#     51076],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 33,
#    'seek': 11196,
#    'start': 126.19999999999999,
#    'end': 129.6,
#    'text': " even for senior engineering roles, sometimes it's asked.",
#    'tokens': [51076,
#     754,
#     337,
#     7965,
#     7043,
#     9604,
#     11,
#     2171,
#     309,
#     311,
#     2351,
#     13,
#     51246],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 34,
#    'seek': 11196,
#    'start': 129.6,
#    'end': 134.44,
#    'text': ' Now before I dive into the exact lead code strategy that I took, I want to talk about',
#    'tokens': [51246,
#     823,
#     949,
#     286,
#     9192,
#     666,
#     264,
#     1900,
#     1477,
#     3089,
#     5206,
#     300,
#     286,
#     1890,
#     11,
#     286,
#     528,
#     281,
#     751,
#     466,
#     51488],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 35,
#    'seek': 11196,
#    'start': 134.44,
#    'end': 135.88,
#    'text': ' DSA fundamentals.',
#    'tokens': [51488, 413, 8886, 29505, 13, 51560],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 36,
#    'seek': 11196,
#    'start': 135.88,
#    'end': 140.2,
#    'text': " If you don't know your DSA fundamentals, you're not going to be efficient with lead",
#    'tokens': [51560,
#     759,
#     291,
#     500,
#     380,
#     458,
#     428,
#     413,
#     8886,
#     29505,
#     11,
#     291,
#     434,
#     406,
#     516,
#     281,
#     312,
#     7148,
#     365,
#     1477,
#     51776],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 37,
#    'seek': 11196,
#    'start': 140.2,
#    'end': 141.2,
#    'text': ' code.',
#    'tokens': [51776, 3089, 13, 51826],
#    'temperature': 0.0,
#    'avg_logprob': -0.12937654767717635,
#    'compression_ratio': 1.732899022801303,
#    'no_speech_prob': 0.03307954594492912},
#   {'id': 38,
#    'seek': 14120,
#    'start': 141.44,
#    'end': 146.88,
#    'text': " In fact, many of the interviews that I've taken in the past have asked me the most basic",
#    'tokens': [50376,
#     682,
#     1186,
#     11,
#     867,
#     295,
#     264,
#     12318,
#     300,
#     286,
#     600,
#     2726,
#     294,
#     264,
#     1791,
#     362,
#     2351,
#     385,
#     264,
#     881,
#     3875,
#     50648],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 39,
#    'seek': 14120,
#    'start': 146.88,
#    'end': 150.51999999999998,
#    'text': ' question that I learned back in like second year of college.',
#    'tokens': [50648,
#     1168,
#     300,
#     286,
#     3264,
#     646,
#     294,
#     411,
#     1150,
#     1064,
#     295,
#     3859,
#     13,
#     50830],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 40,
#    'seek': 14120,
#    'start': 150.51999999999998,
#    'end': 155.16,
#    'text': ' For example, one of my interview questions in a top company was to implement a hash',
#    'tokens': [50830,
#     1171,
#     1365,
#     11,
#     472,
#     295,
#     452,
#     4049,
#     1651,
#     294,
#     257,
#     1192,
#     2237,
#     390,
#     281,
#     4445,
#     257,
#     22019,
#     51062],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 41,
#    'seek': 14120,
#    'start': 155.16,
#    'end': 158.6,
#    'text': ' map and another one was to implement LRU cache.',
#    'tokens': [51062,
#     4471,
#     293,
#     1071,
#     472,
#     390,
#     281,
#     4445,
#     441,
#     49,
#     52,
#     19459,
#     13,
#     51234],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 42,
#    'seek': 14120,
#    'start': 158.6,
#    'end': 162.95999999999998,
#    'text': " So this is why I say to make sure that you know your DSA fundamentals because you don't",
#    'tokens': [51234,
#     407,
#     341,
#     307,
#     983,
#     286,
#     584,
#     281,
#     652,
#     988,
#     300,
#     291,
#     458,
#     428,
#     413,
#     8886,
#     29505,
#     570,
#     291,
#     500,
#     380,
#     51452],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 43,
#    'seek': 14120,
#    'start': 162.95999999999998,
#    'end': 164.95999999999998,
#    'text': ' know when these questions could be asked.',
#    'tokens': [51452, 458, 562, 613, 1651, 727, 312, 2351, 13, 51552],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 44,
#    'seek': 14120,
#    'start': 164.95999999999998,
#    'end': 169.32,
#    'text': " And the other thing is if you know your fundamentals very well, then you're going to be able to",
#    'tokens': [51552,
#     400,
#     264,
#     661,
#     551,
#     307,
#     498,
#     291,
#     458,
#     428,
#     29505,
#     588,
#     731,
#     11,
#     550,
#     291,
#     434,
#     516,
#     281,
#     312,
#     1075,
#     281,
#     51770],
#    'temperature': 0.0,
#    'avg_logprob': -0.13870121183849515,
#    'compression_ratio': 1.7482758620689656,
#    'no_speech_prob': 0.1037045493721962},
#   {'id': 45,
#    'seek': 16932,
#    'start': 169.35999999999999,
#    'end': 174.2,
#    'text': " choose the correct data structure or algorithm that's required in order to solve a lead",
#    'tokens': [50366,
#     2826,
#     264,
#     3006,
#     1412,
#     3877,
#     420,
#     9284,
#     300,
#     311,
#     4739,
#     294,
#     1668,
#     281,
#     5039,
#     257,
#     1477,
#     50608],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 46,
#    'seek': 16932,
#    'start': 174.2,
#    'end': 175.2,
#    'text': ' code problem.',
#    'tokens': [50608, 3089, 1154, 13, 50658],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 47,
#    'seek': 16932,
#    'start': 175.2,
#    'end': 179.79999999999998,
#    'text': " Now let's finally move on to the exact lead code strategy I used in order to crack all",
#    'tokens': [50658,
#     823,
#     718,
#     311,
#     2721,
#     1286,
#     322,
#     281,
#     264,
#     1900,
#     1477,
#     3089,
#     5206,
#     286,
#     1143,
#     294,
#     1668,
#     281,
#     6226,
#     439,
#     50888],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 48,
#    'seek': 16932,
#    'start': 179.79999999999998,
#    'end': 181.12,
#    'text': ' these fake companies.',
#    'tokens': [50888, 613, 7592, 3431, 13, 50954],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 49,
#    'seek': 16932,
#    'start': 181.12,
#    'end': 185.64,
#    'text': " Number one, I suggest you get lead code premium or at least the CTC I've bought.",
#    'tokens': [50954,
#     5118,
#     472,
#     11,
#     286,
#     3402,
#     291,
#     483,
#     1477,
#     3089,
#     12049,
#     420,
#     412,
#     1935,
#     264,
#     383,
#     18238,
#     286,
#     600,
#     4243,
#     13,
#     51180],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 50,
#    'seek': 16932,
#    'start': 185.64,
#    'end': 189.2,
#    'text': " I don't think lead code premium is required when you're just starting off, but if you're",
#    'tokens': [51180,
#     286,
#     500,
#     380,
#     519,
#     1477,
#     3089,
#     12049,
#     307,
#     4739,
#     562,
#     291,
#     434,
#     445,
#     2891,
#     766,
#     11,
#     457,
#     498,
#     291,
#     434,
#     51358],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 51,
#    'seek': 16932,
#    'start': 189.2,
#    'end': 194.12,
#    'text': ' within one to two month mark of your interviews, I highly recommend getting the lead code premium',
#    'tokens': [51358,
#     1951,
#     472,
#     281,
#     732,
#     1618,
#     1491,
#     295,
#     428,
#     12318,
#     11,
#     286,
#     5405,
#     2748,
#     1242,
#     264,
#     1477,
#     3089,
#     12049,
#     51604],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 52,
#    'seek': 16932,
#    'start': 194.12,
#    'end': 198.04,
#    'text': ' so that you can solve the most frequently asked company questions.',
#    'tokens': [51604,
#     370,
#     300,
#     291,
#     393,
#     5039,
#     264,
#     881,
#     10374,
#     2351,
#     2237,
#     1651,
#     13,
#     51800],
#    'temperature': 0.0,
#    'avg_logprob': -0.17776898604172928,
#    'compression_ratio': 1.792763157894737,
#    'no_speech_prob': 0.011331237852573395},
#   {'id': 53,
#    'seek': 19804,
#    'start': 198.04,
#    'end': 202.48,
#    'text': ' And I truly think that CTC I book is very good to have just again to brush over your',
#    'tokens': [50364,
#     400,
#     286,
#     4908,
#     519,
#     300,
#     383,
#     18238,
#     286,
#     1446,
#     307,
#     588,
#     665,
#     281,
#     362,
#     445,
#     797,
#     281,
#     5287,
#     670,
#     428,
#     50586],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 54,
#    'seek': 19804,
#    'start': 202.48,
#    'end': 206.84,
#    'text': ' fundamentals and kind of review the answers and how you go about thinking them in the',
#    'tokens': [50586,
#     29505,
#     293,
#     733,
#     295,
#     3131,
#     264,
#     6338,
#     293,
#     577,
#     291,
#     352,
#     466,
#     1953,
#     552,
#     294,
#     264,
#     50804],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 55,
#    'seek': 19804,
#    'start': 206.84,
#    'end': 207.84,
#    'text': ' first place.',
#    'tokens': [50804, 700, 1081, 13, 50854],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 56,
#    'seek': 19804,
#    'start': 207.84,
#    'end': 212.23999999999998,
#    'text': ' Now the exact strategy that I took is that number one, you want to go over arrays, link',
#    'tokens': [50854,
#     823,
#     264,
#     1900,
#     5206,
#     300,
#     286,
#     1890,
#     307,
#     300,
#     1230,
#     472,
#     11,
#     291,
#     528,
#     281,
#     352,
#     670,
#     41011,
#     11,
#     2113,
#     51074],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 57,
#    'seek': 19804,
#    'start': 212.23999999999998,
#    'end': 213.44,
#    'text': ' list and maps.',
#    'tokens': [51074, 1329, 293, 11317, 13, 51134],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 58,
#    'seek': 19804,
#    'start': 213.44,
#    'end': 217.44,
#    'text': ' Now obviously, first of all, you want to make sure that you understand what these data structures',
#    'tokens': [51134,
#     823,
#     2745,
#     11,
#     700,
#     295,
#     439,
#     11,
#     291,
#     528,
#     281,
#     652,
#     988,
#     300,
#     291,
#     1223,
#     437,
#     613,
#     1412,
#     9227,
#     51334],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 59,
#    'seek': 19804,
#    'start': 217.44,
#    'end': 220.16,
#    'text': ' are and exactly why you use them.',
#    'tokens': [51334, 366, 293, 2293, 983, 291, 764, 552, 13, 51470],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 60,
#    'seek': 19804,
#    'start': 220.16,
#    'end': 224.84,
#    'text': " So it doesn't exactly matter how many questions you do for each of these categories, but you",
#    'tokens': [51470,
#     407,
#     309,
#     1177,
#     380,
#     2293,
#     1871,
#     577,
#     867,
#     1651,
#     291,
#     360,
#     337,
#     1184,
#     295,
#     613,
#     10479,
#     11,
#     457,
#     291,
#     51704],
#    'temperature': 0.0,
#    'avg_logprob': -0.1377365683007428,
#    'compression_ratio': 1.7090301003344481,
#    'no_speech_prob': 0.013634887523949146},
#   {'id': 61,
#    'seek': 22484,
#    'start': 224.84,
#    'end': 228.92000000000002,
#    'text': ' need to be able to figure out what wording each of these questions are using that kind',
#    'tokens': [50364,
#     643,
#     281,
#     312,
#     1075,
#     281,
#     2573,
#     484,
#     437,
#     47602,
#     1184,
#     295,
#     613,
#     1651,
#     366,
#     1228,
#     300,
#     733,
#     50568],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 62,
#    'seek': 22484,
#    'start': 228.92000000000002,
#    'end': 231.88,
#    'text': ' of direct you to a specific data structure or algorithm.',
#    'tokens': [50568,
#     295,
#     2047,
#     291,
#     281,
#     257,
#     2685,
#     1412,
#     3877,
#     420,
#     9284,
#     13,
#     50716],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 63,
#    'seek': 22484,
#    'start': 231.88,
#    'end': 236.76,
#    'text': ' So after you do arrays, link list and map, I would move on to searching algorithms, sorting',
#    'tokens': [50716,
#     407,
#     934,
#     291,
#     360,
#     41011,
#     11,
#     2113,
#     1329,
#     293,
#     4471,
#     11,
#     286,
#     576,
#     1286,
#     322,
#     281,
#     10808,
#     14642,
#     11,
#     32411,
#     50960],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 64,
#    'seek': 22484,
#    'start': 236.76,
#    'end': 238.72,
#    'text': ' algorithms and trees.',
#    'tokens': [50960, 14642, 293, 5852, 13, 51058],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 65,
#    'seek': 22484,
#    'start': 238.72,
#    'end': 242.2,
#    'text': " When you're an intern, most of the questions you're going to be asked is going to be within",
#    'tokens': [51058,
#     1133,
#     291,
#     434,
#     364,
#     2154,
#     11,
#     881,
#     295,
#     264,
#     1651,
#     291,
#     434,
#     516,
#     281,
#     312,
#     2351,
#     307,
#     516,
#     281,
#     312,
#     1951,
#     51232],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 66,
#    'seek': 22484,
#    'start': 242.2,
#    'end': 243.8,
#    'text': ' these first two categories.',
#    'tokens': [51232, 613, 700, 732, 10479, 13, 51312],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 67,
#    'seek': 22484,
#    'start': 243.8,
#    'end': 246.16,
#    'text': " So you want to make sure that you're super, super good at these.",
#    'tokens': [51312,
#     407,
#     291,
#     528,
#     281,
#     652,
#     988,
#     300,
#     291,
#     434,
#     1687,
#     11,
#     1687,
#     665,
#     412,
#     613,
#     13,
#     51430],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 68,
#    'seek': 22484,
#    'start': 246.16,
#    'end': 251.6,
#    'text': ' You want to know your pre in and post-order traversals for the binary trees.',
#    'tokens': [51430,
#     509,
#     528,
#     281,
#     458,
#     428,
#     659,
#     294,
#     293,
#     2183,
#     12,
#     4687,
#     23149,
#     1124,
#     337,
#     264,
#     17434,
#     5852,
#     13,
#     51702],
#    'temperature': 0.0,
#    'avg_logprob': -0.14100230290339544,
#    'compression_ratio': 1.7958477508650519,
#    'no_speech_prob': 0.050324149429798126},
#   {'id': 69,
#    'seek': 25160,
#    'start': 251.6,
#    'end': 255.76,
#    'text': ' And then for the searching and sorting algorithms, you want to know how to implement them, especially',
#    'tokens': [50364,
#     400,
#     550,
#     337,
#     264,
#     10808,
#     293,
#     32411,
#     14642,
#     11,
#     291,
#     528,
#     281,
#     458,
#     577,
#     281,
#     4445,
#     552,
#     11,
#     2318,
#     50572],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 70,
#    'seek': 25160,
#    'start': 255.76,
#    'end': 259.44,
#    'text': ' your binary search, linear search and quick sorts.',
#    'tokens': [50572,
#     428,
#     17434,
#     3164,
#     11,
#     8213,
#     3164,
#     293,
#     1702,
#     7527,
#     13,
#     50756],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 71,
#    'seek': 25160,
#    'start': 259.44,
#    'end': 264.52,
#    'text': ' And also again, know the time complexity and space complexity of these algorithms, especially',
#    'tokens': [50756,
#     400,
#     611,
#     797,
#     11,
#     458,
#     264,
#     565,
#     14024,
#     293,
#     1901,
#     14024,
#     295,
#     613,
#     14642,
#     11,
#     2318,
#     51010],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 72,
#    'seek': 25160,
#    'start': 264.52,
#    'end': 266.28,
#    'text': ' when you apply them in a problem.',
#    'tokens': [51010, 562, 291, 3079, 552, 294, 257, 1154, 13, 51098],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 73,
#    'seek': 25160,
#    'start': 266.28,
#    'end': 270.12,
#    'text': " Now moving on after you've done a couple of questions in these categories, you want to",
#    'tokens': [51098,
#     823,
#     2684,
#     322,
#     934,
#     291,
#     600,
#     1096,
#     257,
#     1916,
#     295,
#     1651,
#     294,
#     613,
#     10479,
#     11,
#     291,
#     528,
#     281,
#     51290],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 74,
#    'seek': 25160,
#    'start': 270.12,
#    'end': 273.44,
#    'text': ' do one through 50 on link code in order.',
#    'tokens': [51290,
#     360,
#     472,
#     807,
#     2625,
#     322,
#     2113,
#     3089,
#     294,
#     1668,
#     13,
#     51456],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 75,
#    'seek': 25160,
#    'start': 273.44,
#    'end': 277.76,
#    'text': ' I think these questions give you a pretty good understanding of how to apply these algorithms',
#    'tokens': [51456,
#     286,
#     519,
#     613,
#     1651,
#     976,
#     291,
#     257,
#     1238,
#     665,
#     3701,
#     295,
#     577,
#     281,
#     3079,
#     613,
#     14642,
#     51672],
#    'temperature': 0.0,
#    'avg_logprob': -0.1558394136682021,
#    'compression_ratio': 1.8254545454545454,
#    'no_speech_prob': 0.04335780441761017},
#   {'id': 76,
#    'seek': 27776,
#    'start': 277.76,
#    'end': 281.64,
#    'text': ' as well as data structures before moving on to the more complex ones.',
#    'tokens': [50364,
#     382,
#     731,
#     382,
#     1412,
#     9227,
#     949,
#     2684,
#     322,
#     281,
#     264,
#     544,
#     3997,
#     2306,
#     13,
#     50558],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 77,
#    'seek': 27776,
#    'start': 281.64,
#    'end': 285.68,
#    'text': ' Now the second part of this roadmap is really for your new grads and senior engineering',
#    'tokens': [50558,
#     823,
#     264,
#     1150,
#     644,
#     295,
#     341,
#     35738,
#     307,
#     534,
#     337,
#     428,
#     777,
#     2771,
#     82,
#     293,
#     7965,
#     7043,
#     50760],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 78,
#    'seek': 27776,
#    'start': 285.68,
#    'end': 286.68,
#    'text': ' roles.',
#    'tokens': [50760, 9604, 13, 50810],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 79,
#    'seek': 27776,
#    'start': 286.68,
#    'end': 290.92,
#    'text': " You're most likely not going to be asked link list type of questions, but still make",
#    'tokens': [50810,
#     509,
#     434,
#     881,
#     3700,
#     406,
#     516,
#     281,
#     312,
#     2351,
#     2113,
#     1329,
#     2010,
#     295,
#     1651,
#     11,
#     457,
#     920,
#     652,
#     51022],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 80,
#    'seek': 27776,
#    'start': 290.92,
#    'end': 292.52,
#    'text': ' sure that you know about these.',
#    'tokens': [51022, 988, 300, 291, 458, 466, 613, 13, 51102],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 81,
#    'seek': 27776,
#    'start': 292.52,
#    'end': 297.64,
#    'text': ' Instead, what you want to focus on is graphs, backtracking algorithms, recursion, heaps',
#    'tokens': [51102,
#     7156,
#     11,
#     437,
#     291,
#     528,
#     281,
#     1879,
#     322,
#     307,
#     24877,
#     11,
#     646,
#     6903,
#     14134,
#     14642,
#     11,
#     20560,
#     313,
#     11,
#     415,
#     2382,
#     51358],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 82,
#    'seek': 27776,
#    'start': 297.64,
#    'end': 300.64,
#    'text': " and priority queues, especially when you're applying to FANG.",
#    'tokens': [51358,
#     293,
#     9365,
#     631,
#     1247,
#     11,
#     2318,
#     562,
#     291,
#     434,
#     9275,
#     281,
#     479,
#     12419,
#     13,
#     51508],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 83,
#    'seek': 27776,
#    'start': 300.64,
#    'end': 304.76,
#    'text': " There's a lot of different sorts of problems that is going to use at least one, if not",
#    'tokens': [51508,
#     821,
#     311,
#     257,
#     688,
#     295,
#     819,
#     7527,
#     295,
#     2740,
#     300,
#     307,
#     516,
#     281,
#     764,
#     412,
#     1935,
#     472,
#     11,
#     498,
#     406,
#     51714],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 84,
#    'seek': 27776,
#    'start': 304.76,
#    'end': 307.59999999999997,
#    'text': ' two of these different data structures and algorithms.',
#    'tokens': [51714, 732, 295, 613, 819, 1412, 9227, 293, 14642, 13, 51856],
#    'temperature': 0.0,
#    'avg_logprob': -0.14098442776102416,
#    'compression_ratio': 1.6902654867256637,
#    'no_speech_prob': 0.09806562960147858},
#   {'id': 85,
#    'seek': 30760,
#    'start': 307.6,
#    'end': 309.32000000000005,
#    'text': ' And these questions can be complex.',
#    'tokens': [50364, 400, 613, 1651, 393, 312, 3997, 13, 50450],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 86,
#    'seek': 30760,
#    'start': 309.32000000000005,
#    'end': 313.24,
#    'text': ' So you really want to make sure that you know how to combine these things together.',
#    'tokens': [50450,
#     407,
#     291,
#     534,
#     528,
#     281,
#     652,
#     988,
#     300,
#     291,
#     458,
#     577,
#     281,
#     10432,
#     613,
#     721,
#     1214,
#     13,
#     50646],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 87,
#    'seek': 30760,
#    'start': 313.24,
#    'end': 318.20000000000005,
#    'text': ' And if you do blind 75 or blind 150 next, depending on how much time you have, I think',
#    'tokens': [50646,
#     400,
#     498,
#     291,
#     360,
#     6865,
#     9562,
#     420,
#     6865,
#     8451,
#     958,
#     11,
#     5413,
#     322,
#     577,
#     709,
#     565,
#     291,
#     362,
#     11,
#     286,
#     519,
#     50894],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 88,
#    'seek': 30760,
#    'start': 318.20000000000005,
#    'end': 322.52000000000004,
#    'text': " you're going to have a solid basic understanding of what these bigger companies require.",
#    'tokens': [50894,
#     291,
#     434,
#     516,
#     281,
#     362,
#     257,
#     5100,
#     3875,
#     3701,
#     295,
#     437,
#     613,
#     3801,
#     3431,
#     3651,
#     13,
#     51110],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 89,
#    'seek': 30760,
#    'start': 322.52000000000004,
#    'end': 326.28000000000003,
#    'text': ' What you want to focus on next is DP, tries and union sets.',
#    'tokens': [51110,
#     708,
#     291,
#     528,
#     281,
#     1879,
#     322,
#     958,
#     307,
#     42796,
#     11,
#     9898,
#     293,
#     11671,
#     6352,
#     13,
#     51298],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 90,
#    'seek': 30760,
#    'start': 326.28000000000003,
#    'end': 330.56,
#    'text': " I know DP is everyone's favorite and I know it's very difficult.",
#    'tokens': [51298,
#     286,
#     458,
#     42796,
#     307,
#     1518,
#     311,
#     2954,
#     293,
#     286,
#     458,
#     309,
#     311,
#     588,
#     2252,
#     13,
#     51512],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 91,
#    'seek': 30760,
#    'start': 330.56,
#    'end': 335.52000000000004,
#    'text': " So most of the time you're probably not going to be asked DP problems, but you never know.",
#    'tokens': [51512,
#     407,
#     881,
#     295,
#     264,
#     565,
#     291,
#     434,
#     1391,
#     406,
#     516,
#     281,
#     312,
#     2351,
#     42796,
#     2740,
#     11,
#     457,
#     291,
#     1128,
#     458,
#     13,
#     51760],
#    'temperature': 0.0,
#    'avg_logprob': -0.12343945354223251,
#    'compression_ratio': 1.6644951140065147,
#    'no_speech_prob': 0.005910681094974279},
#   {'id': 92,
#    'seek': 33552,
#    'start': 335.52,
#    'end': 341.84,
#    'text': ' So you want to at least practice 20, 30 questions of these before kind of giving up.',
#    'tokens': [50364,
#     407,
#     291,
#     528,
#     281,
#     412,
#     1935,
#     3124,
#     945,
#     11,
#     2217,
#     1651,
#     295,
#     613,
#     949,
#     733,
#     295,
#     2902,
#     493,
#     13,
#     50680],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 93,
#    'seek': 33552,
#    'start': 341.84,
#    'end': 346.44,
#    'text': ' I think tries and union sets are very good structures to know as well.',
#    'tokens': [50680,
#     286,
#     519,
#     9898,
#     293,
#     11671,
#     6352,
#     366,
#     588,
#     665,
#     9227,
#     281,
#     458,
#     382,
#     731,
#     13,
#     50910],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 94,
#    'seek': 33552,
#    'start': 346.44,
#    'end': 350.12,
#    'text': " Once you kind of say that to an interviewer, they're going to be very impressed that you",
#    'tokens': [50910,
#     3443,
#     291,
#     733,
#     295,
#     584,
#     300,
#     281,
#     364,
#     4049,
#     260,
#     11,
#     436,
#     434,
#     516,
#     281,
#     312,
#     588,
#     11679,
#     300,
#     291,
#     51094],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 95,
#    'seek': 33552,
#    'start': 350.12,
#    'end': 352.03999999999996,
#    'text': ' thought of these data structures.',
#    'tokens': [51094, 1194, 295, 613, 1412, 9227, 13, 51190],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 96,
#    'seek': 33552,
#    'start': 352.03999999999996,
#    'end': 355.29999999999995,
#    'text': " So it's going to give you brownie points, but these are definitely the structures and",
#    'tokens': [51190,
#     407,
#     309,
#     311,
#     516,
#     281,
#     976,
#     291,
#     6292,
#     414,
#     2793,
#     11,
#     457,
#     613,
#     366,
#     2138,
#     264,
#     9227,
#     293,
#     51353],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 97,
#    'seek': 33552,
#    'start': 355.29999999999995,
#    'end': 359.52,
#    'text': " algorithms that you want to learn at the very end when you're already good at your medium",
#    'tokens': [51353,
#     14642,
#     300,
#     291,
#     528,
#     281,
#     1466,
#     412,
#     264,
#     588,
#     917,
#     562,
#     291,
#     434,
#     1217,
#     665,
#     412,
#     428,
#     6399,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 98,
#    'seek': 33552,
#    'start': 359.52,
#    'end': 361.03999999999996,
#    'text': ' and hard level problems.',
#    'tokens': [51564, 293, 1152, 1496, 2740, 13, 51640],
#    'temperature': 0.0,
#    'avg_logprob': -0.1315491179115752,
#    'compression_ratio': 1.723021582733813,
#    'no_speech_prob': 0.004468179307878017},
#   {'id': 99,
#    'seek': 36104,
#    'start': 361.04,
#    'end': 365.72,
#    'text': " Now finally, I want to address what to do when you're stuck in the middle of a tech",
#    'tokens': [50364,
#     823,
#     2721,
#     11,
#     286,
#     528,
#     281,
#     2985,
#     437,
#     281,
#     360,
#     562,
#     291,
#     434,
#     5541,
#     294,
#     264,
#     2808,
#     295,
#     257,
#     7553,
#     50598],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 100,
#    'seek': 36104,
#    'start': 365.72,
#    'end': 366.72,
#    'text': ' interview.',
#    'tokens': [50598, 4049, 13, 50648],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 101,
#    'seek': 36104,
#    'start': 366.72,
#    'end': 370.28000000000003,
#    'text': " Obviously, the first thing is make sure you're getting the brute force solution out.",
#    'tokens': [50648,
#     7580,
#     11,
#     264,
#     700,
#     551,
#     307,
#     652,
#     988,
#     291,
#     434,
#     1242,
#     264,
#     47909,
#     3464,
#     3827,
#     484,
#     13,
#     50826],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 102,
#    'seek': 36104,
#    'start': 370.28000000000003,
#    'end': 374.32000000000005,
#    'text': " But while you're doing that, make sure that you're thinking of what other data structure",
#    'tokens': [50826,
#     583,
#     1339,
#     291,
#     434,
#     884,
#     300,
#     11,
#     652,
#     988,
#     300,
#     291,
#     434,
#     1953,
#     295,
#     437,
#     661,
#     1412,
#     3877,
#     51028],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 103,
#    'seek': 36104,
#    'start': 374.32000000000005,
#    'end': 377.40000000000003,
#    'text': ' algorithm you can use to make your solution better.',
#    'tokens': [51028,
#     9284,
#     291,
#     393,
#     764,
#     281,
#     652,
#     428,
#     3827,
#     1101,
#     13,
#     51182],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 104,
#    'seek': 36104,
#    'start': 377.40000000000003,
#    'end': 380.92,
#    'text': " Cause that's a hundred percent going to be the follow up question.",
#    'tokens': [51182,
#     10865,
#     300,
#     311,
#     257,
#     3262,
#     3043,
#     516,
#     281,
#     312,
#     264,
#     1524,
#     493,
#     1168,
#     13,
#     51358],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 105,
#    'seek': 36104,
#    'start': 380.92,
#    'end': 382.12,
#    'text': ' If you have time left.',
#    'tokens': [51358, 759, 291, 362, 565, 1411, 13, 51418],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 106,
#    'seek': 36104,
#    'start': 382.12,
#    'end': 386.8,
#    'text': " Second thing is make sure you're asking your clarification questions upfront and kind of",
#    'tokens': [51418,
#     5736,
#     551,
#     307,
#     652,
#     988,
#     291,
#     434,
#     3365,
#     428,
#     34449,
#     1651,
#     30264,
#     293,
#     733,
#     295,
#     51652],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 107,
#    'seek': 36104,
#    'start': 386.8,
#    'end': 390.6,
#    'text': ' making sure that you and your interviewer are on the same page.',
#    'tokens': [51652,
#     1455,
#     988,
#     300,
#     291,
#     293,
#     428,
#     4049,
#     260,
#     366,
#     322,
#     264,
#     912,
#     3028,
#     13,
#     51842],
#    'temperature': 0.0,
#    'avg_logprob': -0.1718447348650764,
#    'compression_ratio': 1.8338762214983713,
#    'no_speech_prob': 0.008314848877489567},
#   {'id': 108,
#    'seek': 39060,
#    'start': 390.64000000000004,
#    'end': 394.08000000000004,
#    'text': " You don't want to be going down the wrong path and figure out that you're on the wrong",
#    'tokens': [50366,
#     509,
#     500,
#     380,
#     528,
#     281,
#     312,
#     516,
#     760,
#     264,
#     2085,
#     3100,
#     293,
#     2573,
#     484,
#     300,
#     291,
#     434,
#     322,
#     264,
#     2085,
#     50538],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 109,
#    'seek': 39060,
#    'start': 394.08000000000004,
#    'end': 397.6,
#    'text': ' path 20 to 30 minutes later in your interview.',
#    'tokens': [50538,
#     3100,
#     945,
#     281,
#     2217,
#     2077,
#     1780,
#     294,
#     428,
#     4049,
#     13,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 110,
#    'seek': 39060,
#    'start': 397.6,
#    'end': 400.6,
#    'text': ' So really ask upfront, does this make sense to you?',
#    'tokens': [50714,
#     407,
#     534,
#     1029,
#     30264,
#     11,
#     775,
#     341,
#     652,
#     2020,
#     281,
#     291,
#     30,
#     50864],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 111,
#    'seek': 39060,
#    'start': 400.6,
#    'end': 404.6,
#    'text': " And if you're genuinely stuck in the interview, just ask for a hint.",
#    'tokens': [50864,
#     400,
#     498,
#     291,
#     434,
#     17839,
#     5541,
#     294,
#     264,
#     4049,
#     11,
#     445,
#     1029,
#     337,
#     257,
#     12075,
#     13,
#     51064],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 112,
#    'seek': 39060,
#    'start': 404.6,
#    'end': 408.6,
#    'text': ' I think the worst thing for an interviewer is if you give up on a problem.',
#    'tokens': [51064,
#     286,
#     519,
#     264,
#     5855,
#     551,
#     337,
#     364,
#     4049,
#     260,
#     307,
#     498,
#     291,
#     976,
#     493,
#     322,
#     257,
#     1154,
#     13,
#     51264],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 113,
#    'seek': 39060,
#    'start': 408.6,
#    'end': 412.88,
#    'text': ' Remember that an interviewer has been in the same exact seat that you are in currently.',
#    'tokens': [51264,
#     5459,
#     300,
#     364,
#     4049,
#     260,
#     575,
#     668,
#     294,
#     264,
#     912,
#     1900,
#     6121,
#     300,
#     291,
#     366,
#     294,
#     4362,
#     13,
#     51478],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 114,
#    'seek': 39060,
#    'start': 412.88,
#    'end': 414.84000000000003,
#    'text': ' So really they want to try to help you.',
#    'tokens': [51478, 407, 534, 436, 528, 281, 853, 281, 854, 291, 13, 51576],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 115,
#    'seek': 39060,
#    'start': 414.84000000000003,
#    'end': 417.96000000000004,
#    'text': " It's just that you need to ask for it and ask for it correctly.",
#    'tokens': [51576,
#     467,
#     311,
#     445,
#     300,
#     291,
#     643,
#     281,
#     1029,
#     337,
#     309,
#     293,
#     1029,
#     337,
#     309,
#     8944,
#     13,
#     51732],
#    'temperature': 0.0,
#    'avg_logprob': -0.12262113543524258,
#    'compression_ratio': 1.8475177304964538,
#    'no_speech_prob': 0.0780600756406784},
#   {'id': 116,
#    'seek': 41796,
#    'start': 417.96,
#    'end': 421.4,
#    'text': " The interviewer is just trying to make sure that you're a person that they can work with.",
#    'tokens': [50364,
#     440,
#     4049,
#     260,
#     307,
#     445,
#     1382,
#     281,
#     652,
#     988,
#     300,
#     291,
#     434,
#     257,
#     954,
#     300,
#     436,
#     393,
#     589,
#     365,
#     13,
#     50536],
#    'temperature': 0.0,
#    'avg_logprob': -0.15414067861196157,
#    'compression_ratio': 1.546448087431694,
#    'no_speech_prob': 0.6331509947776794},
#   {'id': 117,
#    'seek': 41796,
#    'start': 421.4,
#    'end': 423.28,
#    'text': " They're not trying to reject you.",
#    'tokens': [50536, 814, 434, 406, 1382, 281, 8248, 291, 13, 50630],
#    'temperature': 0.0,
#    'avg_logprob': -0.15414067861196157,
#    'compression_ratio': 1.546448087431694,
#    'no_speech_prob': 0.6331509947776794},
#   {'id': 118,
#    'seek': 41796,
#    'start': 423.28,
#    'end': 426.91999999999996,
#    'text': ' If you liked this video, then make sure to give it a thumbs up and make sure to subscribe',
#    'tokens': [50630,
#     759,
#     291,
#     4501,
#     341,
#     960,
#     11,
#     550,
#     652,
#     988,
#     281,
#     976,
#     309,
#     257,
#     8838,
#     493,
#     293,
#     652,
#     988,
#     281,
#     3022,
#     50812],
#    'temperature': 0.0,
#    'avg_logprob': -0.15414067861196157,
#    'compression_ratio': 1.546448087431694,
#    'no_speech_prob': 0.6331509947776794},
#   {'id': 119,
#    'seek': 41796,
#    'start': 426.91999999999996,
#    'end': 428.2,
#    'text': ' to my channel below.',
#    'tokens': [50812, 281, 452, 2269, 2507, 13, 50876],
#    'temperature': 0.0,
#    'avg_logprob': -0.15414067861196157,
#    'compression_ratio': 1.546448087431694,
#    'no_speech_prob': 0.6331509947776794},
#   {'id': 120,
#    'seek': 41796,
#    'start': 428.2,
#    'end': 430.4,
#    'text': ' Let me help you achieve your tech career dreams.',
#    'tokens': [50876,
#     961,
#     385,
#     854,
#     291,
#     4584,
#     428,
#     7553,
#     3988,
#     7505,
#     13,
#     50986],
#    'temperature': 0.0,
#    'avg_logprob': -0.15414067861196157,
#    'compression_ratio': 1.546448087431694,
#    'no_speech_prob': 0.6331509947776794}],
#  'language': 'en'}

# %%
transcript_data = []
for segment in result['segments']:
  transcript_data.append({
      'id' : segment['id'],
      'start' : round(segment['start'],2),
      'end' : round(segment['end'],2),
      'text' : segment['text']
  })

# %%
import pandas as pd
transcript_data = pd.DataFrame(transcript_data)

# %%
transcript_data.head()
# Out:
#    id  start    end                                               text
# 0   0   0.00   4.84   I applied this exact Leak Code strategy and I...
# 1   1   4.84   9.52   Microsoft, Automall, and many more within thr...
# 2   2   9.52  13.34   Hi, my name is Messy Mungle and if you don't ...
# 3   3  13.34  18.56   Google and I created a lot of tech career adv...
# 4   4  18.56  19.68                               now YouTube as well.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)

# %% [markdown]
# # ***PREPROCESSING OF DATA***

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
import re

# %%
filler_words = {
    "um", "uh", "hmm", "erm", "er", "ah", "oh", "like", "you know",
    "i mean", "sort of", "kind of", "actually", "basically",
    "literally", "right", "okay", "well", "so", "just", "you see",
    "you know what I mean", "you get me", "you feel me", "let's see",
    "I guess", "alright", "kinda", "yeah", "mmm", "I suppose"
}
filler_phrases = []
for word in filler_words:
  filler_phrases.append(r"\b"+ re.escape(word) + r"\b")

# %% [markdown]
# functions for text preprocessing

# %%
def remove_adj(text):
  doc = nlp(text)
  keep = []
  for token in doc:
    if token.pos_ == "INTJ":
      continue
    if token.lower_ in {"like","literally","basically"}:
      continue
    keep.append(token.text_with_ws)

  return " ".join(keep)

# %%
def remove_fillers(text):
  for pattern in filler_phrases:
      text = re.sub(pattern,"",text,flags=re.IGNORECASE)
  return text.strip()

# %%
transcript_data['text'] = transcript_data['text'].apply(remove_fillers)
transcript_data['text'] = transcript_data['text'].apply(remove_adj)

# %%
transcript_data
# Out:
#       id   start     end                                               text
# 0      0    0.00    4.84  I  applied  this  exact  Leak  Code  strategy ...
# 1      1    4.84    9.52  Microsoft ,  Automall ,  and  many  more  with...
# 2      2    9.52   13.34  ,  my  name  is  Messy  Mungle  and  if  you  ...
# 3      3   13.34   18.56  Google  and  I  created  a  lot  of  tech  car...
# 4      4   18.56   19.68                                now  YouTube  as  .
# ..   ...     ...     ...                                                ...
# 118  118  423.28  426.92  If  you  liked  this  video ,  then  make  sur...
# 119  119  426.92  428.20                           to  my  channel  below .
# 120  120  428.20  430.40  Let  me  help  you  achieve  your  tech  caree...
# 121  121  428.20  430.40                                  ahaaa  i  got  it
# 122  122  428.20  430.40                                          it  hurts
#
# [123 rows x 4 columns]

# %% [markdown]
# ## ***ANALYSIS OF DATA***

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("intfloat/e5-base-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
transcript_data['text-count'] = transcript_data['text'].apply(lambda x: len(x.split()))
transcript_data['token-count'] = transcript_data['text'].apply(
    lambda x: len(tokenizer.encode(x, add_special_tokens=False))
)

# %%
transcript_data.describe().round(2)
# Out:
#            id   start     end  text-count  token-count
# count  123.00  123.00  123.00      123.00       123.00
# mean    61.00  223.96  227.49       13.24        14.16
# std     35.65  126.66  126.43        5.49         6.11
# min      0.00    0.00    4.84        2.00         2.00
# 25%     30.50  118.26  121.16       10.00        10.00
# 50%     61.00  224.84  228.92       15.00        16.00
# 75%     91.50  333.04  338.68       18.00        19.00
# max    122.00  428.20  430.40       21.00        26.00

# %% [markdown]
# # ***chunking***

# %%
i = 0
index = 0
MAX_TOKENS = 350
transcript_data_after_chunking_together = []

while index < len(transcript_data):
    sum_tokens = 0
    new_text = ""
    start_time = transcript_data.iloc[index]['start']
    end_time = None

    chunk_texts = []

    while index < len(transcript_data) and sum_tokens + transcript_data.iloc[index]['token-count'] <= MAX_TOKENS:
        sum_tokens += transcript_data.iloc[index]['token-count']
        chunk_texts.append(transcript_data.iloc[index]['text'].strip())
        end_time = transcript_data.iloc[index]['end']
        index += 1

    new_text = " ".join(chunk_texts)


    transcript_data_after_chunking_together.append({
        'id': i,
        'start': start_time,
        'end': end_time,
        'text': new_text
    })
    i += 1

# %%
transcript_data_after_chunking_together
# Out:
# [{'id': 0,
#   'start': np.float64(0.0),
#   'end': np.float64(94.64),
#   'text': "I  applied  this  exact  Leak  Code  strategy  and  I  was  able  to  secure  offers  from  Google ,  Amazon , Microsoft ,  Automall ,  and  many  more  within  three  months  of  applying  the  strategy . ,  my  name  is  Messy  Mungle  and  if  you  do n't  already  know  me ,  I 'm  a  software  engineer  at Google  and  I  created  a  lot  of  tech  career  advice  content  on  Instagram ,  LinkedIn ,  and now  YouTube  as  . make  sure  to  hit  the  subscribe  button  and  follow  my  other  pages  as  . the  number  one  thing  that  people  get  stuck  on  is  what  programming  language  do  you  use for  an  interview ? Now  usually  programming  languages  do n't  matter ,  especially  for  fan  companies . unless  you 're  applying  for  a  specific  role  that  requires  you  to  interview  in  a  specific language ,  choose  whatever  language  that  you  are  comfortable  using . Now  I  say  this  with  a  little  grain  of  salt  because  I    failed  one  of  my  interviews because  I  was  using  C++  and  I  know  this  language  executes  faster  than  most  other  languages . However ,  I  got  rejected    because  of  the  sheer  amount  of  lines  of  code  I  had  to  write which  could  have  been  done  in    five  to  10  lines  of  code  if  I  was  to  use  Python . really  what  matters  is  the  speed  of  which  you  program  in  and  how  quickly  you 're  able to  solve  the  problem . my  advice  for  you  when  you 're  choosing  a  programming  language  is    to  first look  at  that  question . If  it 's  a  string  related  question  where  you  have  to  take  an  input  from  the  stream  and then  output  it ,  etc ,  etc ,    use  the  language    Python . It 's  much  faster  than  using  a  language    C++  which  requires  you  to  add  additional  lines of  code    to  process  that  data . But  generally  speaking ,  choosing  a  programming  language  does  not  matter ."},
#  {'id': 1,
#   'start': np.float64(94.64),
#   'end': np.float64(181.12),
#   'text': "Next  let 's  talk  about  time  complexity  and  space  complexity . I  do  not  care  what  phase  of  engineering  you 're  in . If  you 're  an  intern ,  if  you 're  looking  for  a  new  grad ,  if  you 're  looking  for  senior engineering  roles ,  time  and  space  complexity  is  going  to  be  asked . You  should  really  know  all  of  your  own  notations . It 's    this  chart  that  I  always  use  before  going  into  any  interview . You  should  always  be  able  to  look  at  your  code  and  figure  out  what  the  space  and  time complexity  of  your  algorithm  is . This  is  definitely  definitely  going  to  be  asked  if  you 're  an  intern  or  a  new  grad ,  but even  for  senior  engineering  roles ,  sometimes  it 's  asked . Now  before  I  dive  into  the  exact  lead  code  strategy  that  I  took ,  I  want  to  talk  about DSA  fundamentals . If  you  do n't  know  your  DSA  fundamentals ,  you 're  not  going  to  be  efficient  with  lead code . In  fact ,  many  of  the  interviews  that  I 've  taken  in  the  past  have  asked  me  the  most  basic question  that  I  learned  back  in    second  year  of  college . For  example ,  one  of  my  interview  questions  in  a  top  company  was  to  implement  a  hash map  and  another  one  was  to  implement  LRU  cache . this  is  why  I  say  to  make  sure  that    your  DSA  fundamentals  because  you  do n't know  when  these  questions  could  be  asked . And  the  other  thing  is  if    your  fundamentals  very  ,  then  you 're  going  to  be  able  to choose  the  correct  data  structure  or  algorithm  that 's  required  in  order  to  solve  a  lead code  problem . let 's  finally  move  on  to  the  exact  lead  code  strategy  I  used  in  order  to  crack  all these  fake  companies ."},
#  {'id': 2,
#   'start': np.float64(181.12),
#   'end': np.float64(266.28),
#   'text': "Number  one ,  I  suggest  you  get  lead  code  premium  or  at  least  the  CTC  I 've  bought . I  do n't  think  lead  code  premium  is  required  when  you 're    starting  off ,  but  if  you 're within  one  to  two  month  mark  of  your  interviews ,  I  highly  recommend  getting  the  lead  code  premium that  you  can  solve  the  most  frequently  asked  company  questions . And  I  truly  think  that  CTC  I  book  is  very  good  to  have    again  to  brush  over  your fundamentals  and    review  the  answers  and  how  you  go  about  thinking  them  in  the first  place . Now  the  exact  strategy  that  I  took  is  that  number  one ,  you  want  to  go  over  arrays ,  link list  and  maps . Now  obviously ,  first  of  all ,  you  want  to  make  sure  that  you  understand  what  these  data  structures are  and  exactly  why  you  use  them . it  does n't  exactly  matter  how  many  questions  you  do  for  each  of  these  categories ,  but  you need  to  be  able  to  figure  out  what  wording  each  of  these  questions  are  using  that  kind of  direct  you  to  a  specific  data  structure  or  algorithm . after  you  do  arrays ,  link  list  and  map ,  I  would  move  on  to  searching  algorithms ,  sorting algorithms  and  trees . When  you 're  an  intern ,  most  of  the  questions  you 're  going  to  be  asked  is  going  to  be  within these  first  two  categories . you  want  to  make  sure  that  you 're  super ,  super  good  at  these . You  want  to  know  your  pre  in  and  post - order  traversals  for  the  binary  trees . And  then  for  the  searching  and  sorting  algorithms ,  you  want  to  know  how  to  implement  them ,  especially your  binary  search ,  linear  search  and  quick  sorts . And  also  again ,  know  the  time  complexity  and  space  complexity  of  these  algorithms ,  especially when  you  apply  them  in  a  problem ."},
#  {'id': 3,
#   'start': np.float64(266.28),
#   'end': np.float64(352.04),
#   'text': "Now  moving  on  after  you 've  done  a  couple  of  questions  in  these  categories ,  you  want  to do  one  through  50  on  link  code  in  order . I  think  these  questions  give  you  a  pretty  good  understanding  of  how  to  apply  these  algorithms as    as  data  structures  before  moving  on  to  the  more  complex  ones . the  second  part  of  this  roadmap  is  really  for  your  new  grads  and  senior  engineering roles . You 're  most  likely  not  going  to  be  asked  link  list  type  of  questions ,  but  still  make sure  that    about  these . Instead ,  what  you  want  to  focus  on  is  graphs ,  backtracking  algorithms ,  recursion ,  heaps and  priority  queues ,  especially  when  you 're  applying  to  FANG . There 's  a  lot  of  different  sorts  of  problems  that  is  going  to  use  at  least  one ,  if  not two  of  these  different  data  structures  and  algorithms . And  these  questions  can  be  complex . you  really  want  to  make  sure  that    how  to  combine  these  things  together . And  if  you  do  blind  75  or  blind  150  next ,  depending  on  how  much  time  you  have ,  I  think you 're  going  to  have  a  solid  basic  understanding  of  what  these  bigger  companies  require . What  you  want  to  focus  on  next  is  DP ,  tries  and  union  sets . I  know  DP  is  everyone 's  favorite  and  I  know  it 's  very  difficult . most  of  the  time  you 're  probably  not  going  to  be  asked  DP  problems ,  but  you  never  know . you  want  to  at  least  practice  20 ,  30  questions  of  these  before    giving  up . I  think  tries  and  union  sets  are  very  good  structures  to  know  as  . Once  you    say  that  to  an  interviewer ,  they 're  going  to  be  very  impressed  that  you thought  of  these  data  structures ."},
#  {'id': 4,
#   'start': np.float64(352.04),
#   'end': np.float64(428.2),
#   'text': "it 's  going  to  give  you  brownie  points ,  but  these  are  definitely  the  structures  and algorithms  that  you  want  to  learn  at  the  very  end  when  you 're  already  good  at  your  medium and  hard  level  problems . Now  finally ,  I  want  to  address  what  to  do  when  you 're  stuck  in  the  middle  of  a  tech interview . Obviously ,  the  first  thing  is  make  sure  you 're  getting  the  brute  force  solution  out . But  while  you 're  doing  that ,  make  sure  that  you 're  thinking  of  what  other  data  structure algorithm  you  can  use  to  make  your  solution  better . Cause  that 's  a  hundred  percent  going  to  be  the  follow  up  question . If  you  have  time  left . Second  thing  is  make  sure  you 're  asking  your  clarification  questions  upfront  and making  sure  that  you  and  your  interviewer  are  on  the  same  page . You  do n't  want  to  be  going  down  the  wrong  path  and  figure  out  that  you 're  on  the  wrong path  20  to  30  minutes  later  in  your  interview . really  ask  upfront ,  does  this  make  sense  to  you ? And  if  you 're  genuinely  stuck  in  the  interview ,    ask  for  a  hint . I  think  the  worst  thing  for  an  interviewer  is  if  you  give  up  on  a  problem . Remember  that  an  interviewer  has  been  in  the  same  exact  seat  that  you  are  in  currently . really  they  want  to  try  to  help  you . It 's    that  you  need  to  ask  for  it  and  ask  for  it  correctly . The  interviewer  is    trying  to  make  sure  that  you 're  a  person  that  they  can  work  with . They 're  not  trying  to  reject  you . If  you  liked  this  video ,  then  make  sure  to  give  it  a  thumbs  up  and  make  sure  to  subscribe to  my  channel  below ."},
#  {'id': 5,
#   'start': np.float64(428.2),
#   'end': np.float64(430.4),
#   'text': 'Let  me  help  you  achieve  your  tech  career  dreams . ahaaa  i  got  it it  hurts'}]

# %%
transcript_data_after_chunking_together = pd.DataFrame(transcript_data_after_chunking_together)
transcript_data_after_chunking_together
# Out:
#    id   start     end                                               text
# 0   0    0.00   94.64  I  applied  this  exact  Leak  Code  strategy ...
# 1   1   94.64  181.12  Next  let 's  talk  about  time  complexity  a...
# 2   2  181.12  266.28  Number  one ,  I  suggest  you  get  lead  cod...
# 3   3  266.28  352.04  Now  moving  on  after  you 've  done  a  coup...
# 4   4  352.04  428.20  it 's  going  to  give  you  brownie  points ,...
# 5   5  428.20  430.40  Let  me  help  you  achieve  your  tech  caree...

# %%
from sentence_transformers import SentenceTransformer
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device for SentenceTransformer model: {device}")
model = SentenceTransformer('intfloat/e5-base-v2').to(device)
print(f"SentenceTransformer model is on device: {model.device}")
# Out:
# Using device for SentenceTransformer model: cuda
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# SentenceTransformer model is on device: cuda:0

# %%
embeddings = []

for _,element in transcript_data_after_chunking_together.iterrows():
  input_text = "passage: "+ element['text']
  print(f"Processing chunk with text: {input_text[:50]}...") # Print part of the text being processed
  embedding = model.encode(input_text,
                           batch_size = 32,
                           normalize_embeddings=True,
                           convert_to_tensor=True) # Convert to tensor here
  print(f"Embedding tensor is on device: {embedding.device}") # Print device of the embedding tensor
  embeddings.append(embedding.cpu().numpy()) # Move back to CPU and convert to numpy

transcript_data_after_chunking_together['embedding'] = embeddings
# Out:
# Processing chunk with text: passage: I  applied  this  exact  Leak  Code  stra...
# Embedding tensor is on device: cuda:0
# Processing chunk with text: passage: Next  let 's  talk  about  time  complexi...
# Embedding tensor is on device: cuda:0
# Processing chunk with text: passage: Number  one ,  I  suggest  you  get  lead...
# Embedding tensor is on device: cuda:0
# Processing chunk with text: passage: Now  moving  on  after  you 've  done  a ...
# Embedding tensor is on device: cuda:0
# Processing chunk with text: passage: it 's  going  to  give  you  brownie  poi...
# Embedding tensor is on device: cuda:0
# Processing chunk with text: passage: Let  me  help  you  achieve  your  tech  ...
# Embedding tensor is on device: cuda:0

# %%
transcript_data_after_chunking_together
# Out:
#    id   start     end                                               text  \
# 0   0    0.00   94.64  I  applied  this  exact  Leak  Code  strategy ...
# 1   1   94.64  181.12  Next  let 's  talk  about  time  complexity  a...
# 2   2  181.12  266.28  Number  one ,  I  suggest  you  get  lead  cod...
# 3   3  266.28  352.04  Now  moving  on  after  you 've  done  a  coup...
# 4   4  352.04  428.20  it 's  going  to  give  you  brownie  points ,...
# 5   5  428.20  430.40  Let  me  help  you  achieve  your  tech  caree...
#
#                                            embedding
# 0  [0.048758633, -0.05580547, -0.046355322, 0.012...
# 1  [-0.012813714, -0.0072784997, -0.053541053, -0...
# 2  [-0.002432627, -0.038955163, -0.023889303, -0....
# 3  [0.010830883, -0.024413647, -0.04404242, -0.00...
# 4  [0.004646819, -0.040356316, -0.04286418, 0.024...
# 5  [0.00030340138, -0.014475895, -0.027766095, 0....

# %% [markdown]
# # ***RAG***

# %%
import torch

# %%
import numpy as np
import pandas as pd

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
dict_of_chunks = transcript_data_after_chunking_together.to_dict(orient = "records")

embeddings_torch = torch.tensor(np.array(transcript_data_after_chunking_together["embedding"].tolist()), dtype=torch.float32).to(device)

# %%
embeddings_torch.shape
# Out:
# torch.Size([6, 768])

# %%
result['text']
# Out:
# " I applied this exact Leak Code strategy and I was able to secure offers from Google, Amazon, Microsoft, Automall, and many more within three months of applying the strategy. Hi, my name is Messy Mungle and if you don't already know me, I'm a software engineer at Google and I created a lot of tech career advice content on Instagram, LinkedIn, and now YouTube as well. So make sure to hit the subscribe button and follow my other pages as well. So the number one thing that people get stuck on is what programming language do you use for an interview? Now usually programming languages don't matter, especially for fan companies. So unless you're applying for a specific role that requires you to interview in a specific language, choose whatever language that you are comfortable using. Now I say this with a little grain of salt because I actually failed one of my interviews because I was using C++ and I know this language executes faster than most other languages. However, I got rejected just because of the sheer amount of lines of code I had to write which could have been done in basically five to 10 lines of code if I was to use Python. So really what matters is the speed of which you program in and how quickly you're able to solve the problem. So my advice for you when you're choosing a programming language is actually to first look at that question. If it's a string related question where you have to take an input from the stream and then output it, etc, etc, just use the language like Python. It's much faster than using a language like C++ which requires you to add additional lines of code just to process that data. But generally speaking, choosing a programming language does not matter. Next let's talk about time complexity and space complexity. I do not care what phase of engineering you're in. If you're an intern, if you're looking for a new grad, if you're looking for senior engineering roles, time and space complexity is going to be asked. You should really know all of your own notations. It's actually this chart that I always use before going into any interview. You should always be able to look at your code and figure out what the space and time complexity of your algorithm is. This is definitely definitely going to be asked if you're an intern or a new grad, but even for senior engineering roles, sometimes it's asked. Now before I dive into the exact lead code strategy that I took, I want to talk about DSA fundamentals. If you don't know your DSA fundamentals, you're not going to be efficient with lead code. In fact, many of the interviews that I've taken in the past have asked me the most basic question that I learned back in like second year of college. For example, one of my interview questions in a top company was to implement a hash map and another one was to implement LRU cache. So this is why I say to make sure that you know your DSA fundamentals because you don't know when these questions could be asked. And the other thing is if you know your fundamentals very well, then you're going to be able to choose the correct data structure or algorithm that's required in order to solve a lead code problem. Now let's finally move on to the exact lead code strategy I used in order to crack all these fake companies. Number one, I suggest you get lead code premium or at least the CTC I've bought. I don't think lead code premium is required when you're just starting off, but if you're within one to two month mark of your interviews, I highly recommend getting the lead code premium so that you can solve the most frequently asked company questions. And I truly think that CTC I book is very good to have just again to brush over your fundamentals and kind of review the answers and how you go about thinking them in the first place. Now the exact strategy that I took is that number one, you want to go over arrays, link list and maps. Now obviously, first of all, you want to make sure that you understand what these data structures a ...

# %%
# query = "what are the 9 habits"
# query = "query: " + query

# query_embedding = model.encode(query,normalize_embeddings=True,convert_to_tensor = True)

# query_embedding

# %%
from sentence_transformers import util
# dot_scores = util.dot_score(a = query_embedding,b = embeddings_torch)[0]

# %%
# top_k_result = torch.topk(dot_scores , k = 3)

# %%
# top_k_result

# %%
# transcript_data_after_chunking_together.iloc[3]['text']

# %%
# top_k_result_numpy = top_k_result.indices.cpu().numpy()

# %%
# content = "Based on the following context items, please answer the query. Give yourself room to think by extracting relevant passages from the context before answering the query. Dont return the thinking, only return the answer. Make sure your answers are as explanatory as possible." # Initialize before the loop
# for i, index in enumerate(top_k_result_numpy):
#     content += f"content {i}: " + transcript_data_after_chunking_together.iloc[index]['text'] + "start time : "+ str(transcript_data_after_chunking_together.iloc[index]['start'])+'\n'


# content += f"\n" + "answer the query based on the context provided in max 200 words use the start time whenever possible" + '\n' + query

# print(content)

# %%
# def generate_query(user_input){
#     query = "query: " + user_input

#     query_embedding = model.encode(query,normalize_embeddings=True,convert_to_tensor = True)
#     dot_scores = util.dot_score(a = query_embedding,b = embeddings_torch)[0]
#     top_k_result = torch.topk(dot_scores , k = 3)
#     top_k_result_numpy = top_k_result.indices.cpu().numpy()
#     content = "Based on the following context items, please answer the query. Give yourself room to think by extracting relevant passages from the context before answering the query. Dont return the thinking, only return the answer. Make sure your answers are as explanatory as possible." # Initialize before the loop
#     for i, index in enumerate(top_k_result_numpy):
#         content += f"content {i}: " + transcript_data_after_chunking_together.iloc[index]['text'] + "start time : "+ str(transcript_data_after_chunking_together.iloc[index]['start'])+'\n'
#     content += f"\n" + "answer the query based on the context provided in max 200 words use the start time whenever possible" + '\n' + query

# }

def generate_query(user_input):
    query = "query: " + user_input
    content = ""
    query_embedding = model.encode(query, normalize_embeddings=True, convert_to_tensor=True)
    dot_scores = util.dot_score(a=query_embedding, b=embeddings_torch)[0]
    top_k_result = torch.topk(dot_scores, k=3)
    top_k_indices = top_k_result.indices.cpu().numpy()

    for i, index in enumerate(top_k_indices):

        row = transcript_data_after_chunking_together.iloc[index]
        content += f"content {i}: {row['text']} start time: {row['start']}\n"

    content += (
        "\nAnswer the query based on the context provided in max 200 words. "
        "Use the start time whenever possible\n"
        f"{query}"
    )

    return content

# %%
! pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.176.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.7.14)

# %%
import google.generativeai as genai


# client = genai.Client(api_key="AIzaSyChJavhK_2q-3x4c1accRKfiUM9c_xvR1c")
genai.configure(api_key=("AIzaSyDuHc9QbDs6VwpuqiRR6vbkpIi35AvtUz4"))

generation_config = {
  "temperature": 0,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 300,
  "response_mime_type": "text/plain",
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_NONE",
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE",
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE",
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE",
  },
]

instruction = """
You are a structured note-generation assistant built into a productivity app called YouNote.

Your task is to take in transcribed content from long-form sources (YouTube videos, playlists, lectures, or podcasts) and generate clear, concise, and well-structured notes.

Your notes must:
- Use bullet points, headings, and subheadings for readability.
- Extract key concepts, ideas, and facts — no fluff.
- Be written in plain, easy-to-understand language for students and self-learners.
- Preserve the original context and intent of the speaker.
- If the video is a tutorial, highlight steps, code patterns, or tools.
- If the video is theoretical, summarize definitions, examples, and logic flows.
- Avoid repetition or hallucinated content.
- Limit summary to what's present in the actual transcript chunks.

You're part of a multi-step map-reduce summarization system. Each chunk you get may be part of a larger video — so be precise and context-aware, but don’t assume outside knowledge.

Format the output as Markdown-compatible text.
"""

genai_model = genai.GenerativeModel(
  model_name="gemini-2.0-flash",
  safety_settings=safety_settings,
  generation_config=generation_config,
  system_instruction=instruction,
)

# response = client.models.generate_content(
#     model="", contents=content
# )
# print(response.text)

chat_session = genai_model.start_chat(
    history=[]
)

while True:

    user_input = input("You: ")
    print()

    user_input = generate_query(user_input)
    response = chat_session.send_message(user_input)

    model_response = response.text

    print(f'Bot: {model_response}')
    print()


    chat_session.history.append({"role": "user", "parts": [user_input]})
    chat_session.history.append({"role": "model", "parts": [model_response]})
# Out:
# You: whats the video about
#
# Bot: Here's a summary of the video's content, based on the provided chunks:
#
# *   **Advanced Data Structures and Algorithms:** These are good for brownie points, but should be learned after mastering medium and hard-level problems (0:00).
# *   **Handling Tech Interview Stalls:**
#     *   First, provide a brute-force solution while considering better data structures/algorithms.
#     *   Ask clarifying questions upfront to ensure alignment with the interviewer.
#     *   If genuinely stuck, ask for a hint. Interviewers want to help and see if you're someone they can work with (0:00).
# *   **Time and Space Complexity:** Understanding Big O notation is crucial for all engineering levels. Be able to determine the time and space complexity of your code (1:35).
# *   **DSA Fundamentals:** Strong fundamentals are essential for efficient LeetCode practice. Basic questions like implementing a hash map or LRU cache can be asked in interviews (1:44).
#
# You: what do you think about faang companies
#
# Bot: Here's what the provided content suggests about FAANG companies:
#
# *   **Focus for New Grads/Senior Roles:** When applying to FAANG, prioritize graphs, backtracking algorithms, recursion, heaps, and priority queues (2:66). These companies often use problems that combine these data structures and algorithms.
# *   **Language Choice:** Programming language generally doesn't matter for FAANG interviews unless a specific language is required for the role (0:00).
# *   **Author's Success:** The speaker secured offers from Google, Amazon, and Microsoft by using the LeetCode strategy they discuss (2:66).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-48-3752199232.py in <cell line: 0>()
#      70 while True:
#      71
# ---> 72     user_input = input("You: ")
#      73     print()
#      74
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
